# %%
import numpy as np
import pandas as pd

# %%
top_players = pd.read_csv("../data/top5-players.csv")

# %%
top_players
# Out:
#         Rk             Player   Nation    Pos           Squad  \
# 0        1         Max Aarons  eng ENG     DF     Bournemouth
# 1        2   Brenden Aaronson   us USA  MF,FW    Union Berlin
# 2        3    Paxten Aaronson   us USA     MF  Eint Frankfurt
# 3        4  Keyliane Abdallah   fr FRA     FW       Marseille
# 4        5   Yunis Abdelhamid   ma MAR     DF           Reims
# ...    ...                ...      ...    ...             ...
# 2847  2848     Lovro Zvonarek   hr CRO  FW,MF   Bayern Munich
# 2848  2849    Martin Ødegaard   no NOR     MF         Arsenal
# 2849  2850        Milan Đurić   ba BIH     FW   Hellas Verona
# 2850  2851        Milan Đurić   ba BIH     FW           Monza
# 2851  2852   Mateusz Łęgowski   pl POL     MF     Salernitana
#
#                     Comp   Age    Born  MP  Starts  ...  Gls_90  Ast_90  \
# 0     eng Premier League  23.0  2000.0  20      13  ...    0.00    0.07
# 1          de Bundesliga  22.0  2000.0  30      14  ...    0.14    0.14
# ...

# %% [markdown]
# ### Florian Wirtz vs Leverkusen

# %%
leverkusen = top_players[top_players["Squad"] == "Leverkusen"]

# %%
suma_lev = leverkusen.select_dtypes(include='number').sum()

# %%
suma_leverkusen = pd.DataFrame(suma_lev).T
#suma_leverkusen["Jugador"] = "Total"

# %%
leverkusen_final = pd.concat([leverkusen, suma_leverkusen], ignore_index=True)

# %%
ratio_goles_wirtz = (11 / 87) * 100
ratio_asist_wirtz = (11 / 71) * 100
ratio_xag_wirtz = (7.5 / 75.5) * 100
ratio_prgc_wirtz = (138 / 888) * 100
ratio_prgp_wirtz = (224 /1997) * 100
ratio_min_wirtz = (2372 / (34 * 90)) * 100

# %%
print(f"Florian Wirtz ha conseguido el {round(ratio_goles_wirtz, 2)}% de los goles del Leverkusen Uts en la 23/24.")
print(f"Florian Wirtz ha conseguido el {round(ratio_asist_wirtz, 2)}% de las asistencias del Leverkusen en la 23/24.")
print(f"Florian Wirtz ha conseguido el {round(ratio_xag_wirtz, 2)}% de las asistencias esperadas del Leverkusen en la 23/24.")
print(f"Florian Wirtz ha conseguido el {round(ratio_prgp_wirtz, 2)}% de los pases progresivos del Leverkusen en la 23/24.")
print(f"Florian Wirtz ha conseguido el {round(ratio_prgc_wirtz, 2)}% de las conducciones progresivas del Leverkusen en la 23/24.")
print(f"Florian Wirtz a jugado el {round(ratio_min_wirtz, 2)}% de los minutos de la temporada.")
# Out:
# Florian Wirtz ha conseguido el 12.64% de los goles del Leverkusen Uts en la 23/24.
# Florian Wirtz ha conseguido el 15.49% de las asistencias del Leverkusen en la 23/24.
# Florian Wirtz ha conseguido el 9.93% de las asistencias esperadas del Leverkusen en la 23/24.
# Florian Wirtz ha conseguido el 11.22% de los pases progresivos del Leverkusen en la 23/24.
# Florian Wirtz ha conseguido el 15.54% de las conducciones progresivas del Leverkusen en la 23/24.
# Florian Wirtz a jugado el 77.52% de los minutos de la temporada.

# %%
leverkusen_final
# Out:
#          Rk             Player  Nation    Pos       Squad           Comp  \
# 0      28.0         Amine Adli  ma MAR  MF,FW  Leverkusen  de Bundesliga
# 1     103.0       Nadiem Amiri  de GER     MF  Leverkusen  de Bundesliga
# 2     111.0     Robert Andrich  de GER  MF,DF  Leverkusen  de Bundesliga
# 3     144.0             Arthur  br BRA     DF  Leverkusen  de Bundesliga
# 4     339.0    Victor Boniface  ng NGA     FW  Leverkusen  de Bundesliga
# 5     913.0   Jeremie Frimpong  nl NED     DF  Leverkusen  de Bundesliga
# 6    1039.0      Álex Grimaldo  es ESP     DF  Leverkusen  de Bundesliga
# 7    1144.0     Piero Hincapié  ec ECU     DF  Leverkusen  de Bundesliga
# 8    1146.0        Adam Hložek  cz CZE  MF,FW  Leverkusen  de Bundesliga
# 9    1148.0      Jonas Hofmann  de GER     MF  Leverkusen  de Bundesliga
# 10   1162.0     Lukáš Hrádecký  fi FIN     GK  Leverkusen  de Bundesliga
# 11   1179.0     Borja Iglesias  es ESP     FW  Leverkusen  de Bundesliga
# ...

# %% [markdown]
# ### Bruno Guimarães vs Newcastle Utd

# %%
bruno_guimaraes = top_players.loc[top_players["Player"] == "Bruno Guimarães"]

# %%
bruno_guimaraes
# Out:
#         Rk           Player  Nation Pos          Squad                Comp  \
# 1063  1064  Bruno Guimarães  br BRA  MF  Newcastle Utd  eng Premier League
#
#        Age    Born  MP  Starts  ...  Gls_90  Ast_90  G+A_90  G-PK_90  \
# 1063  25.0  1997.0  37      37  ...    0.19    0.22    0.41     0.19
#
#       G+A-PK_90  xG_90  xAG_90  xG+xAG_90  npxG_90  npxG+xAG_90
# 1063       0.41   0.13    0.18       0.31     0.13         0.31
#
# [1 rows x 37 columns]

# %%
newcastle = top_players[top_players["Squad"] == "Newcastle Utd"]

# %%
suma_newc = newcastle.select_dtypes(include='number').sum()

# %%
suma_newcastle = pd.DataFrame(suma_newc).T
#suma_newcastle["Jugador"] = "Total"

# %%
newcastle_final = pd.concat([newcastle, suma_newcastle], ignore_index=True)

# %%
ratio_goles_bruno = (7 / 83) * 100
ratio_asist_bruno = (8 / 55) * 100
ratio_xag_bruno = (6.4 / 55.5) * 100
ratio_prgc_bruno = (65 / 737) * 100
ratio_prgp_bruno = (283 / 1557) * 100
ratio_min_bruno = (3263 / (38 * 90)) * 100

# %%
print(f"Bruno Guimarães ha conseguido el {round(ratio_goles_bruno, 2)}% de los goles del Newcastle Uts en la 23/24.")
print(f"Bruno Guimarães ha conseguido el {round(ratio_asist_bruno, 2)}% de las asistencias del Newcastle Uts en la 23/24.")
print(f"Bruno Guimarães ha conseguido el {round(ratio_xag_bruno, 2)}% de las asistencias esperadas del Newcastle Uts en la 23/24.")
print(f"Bruno Guimarães ha conseguido el {round(ratio_prgp_bruno, 2)}% de los pases progresivos del Newcastle Uts en la 23/24.")
print(f"Bruno Guimarães ha conseguido el {round(ratio_prgc_bruno, 2)}% de las conducciones progresivas del Newcastle Uts en la 23/24.")
print(f"Bruno Guimarães ha jugado el {round(ratio_min_bruno, 2)}% de los minutos de la temporada.")
# Out:
# Bruno Guimarães ha conseguido el 8.43% de los goles del Newcastle Uts en la 23/24.
# Bruno Guimarães ha conseguido el 14.55% de las asistencias del Newcastle Uts en la 23/24.
# Bruno Guimarães ha conseguido el 11.53% de las asistencias esperadas del Newcastle Uts en la 23/24.
# Bruno Guimarães ha conseguido el 18.18% de los pases progresivos del Newcastle Uts en la 23/24.
# Bruno Guimarães ha conseguido el 8.82% de las conducciones progresivas del Newcastle Uts en la 23/24.
# Bruno Guimarães ha jugado el 95.41% de los minutos de la temporada.

# %% [markdown]
# ### Martin Ødegaard vs Arsenal

# %%
martin_odegaard = top_players.loc[top_players["Player"] == "Martin Ødegaard"]

# %%
martin_odegaard
# Out:
#         Rk           Player  Nation Pos    Squad                Comp   Age  \
# 2848  2849  Martin Ødegaard  no NOR  MF  Arsenal  eng Premier League  24.0
#
#         Born  MP  Starts  ...  Gls_90  Ast_90  G+A_90  G-PK_90  G+A-PK_90  \
# 2848  1998.0  35      35  ...    0.23    0.29    0.52     0.17       0.47
#
#       xG_90  xAG_90  xG+xAG_90  npxG_90  npxG+xAG_90
# 2848   0.22    0.28        0.5     0.17         0.45
#
# [1 rows x 37 columns]

# %%
arsenal = top_players[top_players["Squad"] == "Arsenal"]
suma_ars = arsenal.select_dtypes(include='number').sum()
suma_arsenal = pd.DataFrame(suma_ars).T
#suma_arsenal["Jugador"] = "Total"

# %%
arsenal_final = pd.concat([arsenal, suma_arsenal], ignore_index=True)

# %%
ratio_goles_odegaard = (8 / 86) * 100
ratio_asist_odegaard = (10 / 62) * 100
ratio_xag_odegaard = (9.6 / 55.5) * 100
ratio_prgc_odegaard = (91 / 737) * 100
ratio_prgp_odegaard = (344 / 1557) * 100
ratio_min_odegaard = (3091 / (38 * 90)) * 100

# %%
print(f"Martin Ødegaard ha conseguido el {round(ratio_goles_odegaard, 2)}% de los goles del Arsenal en la 23/24.")
print(f"Martin Ødegaard ha conseguido el {round(ratio_asist_odegaard, 2)}% de las asistencias del Arsenal en la 23/24.")
print(f"Martin Ødegaard ha conseguido el {round(ratio_xag_odegaard, 2)}% de las asistencias esperadas del Arsenal en la 23/24.")
print(f"Martin Ødegaard ha conseguido el {round(ratio_prgp_odegaard, 2)}% de los pases progresivos del Arsenal en la 23/24.")
print(f"Martin Ødegaard ha conseguido el {round(ratio_prgc_odegaard, 2)}% de las conducciones progresivas del Arsenal en la 23/24.")
print(f"Martin Ødegaard ha jugado el {round(ratio_min_odegaard, 2)}% de los minutos de la temporada.")
# Out:
# Martin Ødegaard ha conseguido el 9.3% de los goles del Arsenal en la 23/24.
# Martin Ødegaard ha conseguido el 16.13% de las asistencias del Arsenal en la 23/24.
# Martin Ødegaard ha conseguido el 17.3% de las asistencias esperadas del Arsenal en la 23/24.
# Martin Ødegaard ha conseguido el 22.09% de los pases progresivos del Arsenal en la 23/24.
# Martin Ødegaard ha conseguido el 12.35% de las conducciones progresivas del Arsenal en la 23/24.
# Martin Ødegaard ha jugado el 90.38% de los minutos de la temporada.

# %% [markdown]
# ### Kevin Stöger vs Bochum

# %%
kevin_stoger = top_players.loc[top_players["Player"] == "Kevin Stöger"]

# %%
kevin_stoger
# Out:
#         Rk        Player  Nation Pos   Squad           Comp   Age    Born  MP  \
# 2511  2512  Kevin Stöger  at AUT  MF  Bochum  de Bundesliga  29.0  1993.0  32
#
#       Starts  ...  Gls_90  Ast_90  G+A_90  G-PK_90  G+A-PK_90  xG_90  xAG_90  \
# 2511      32  ...    0.24    0.34    0.57      0.1       0.44   0.21    0.33
#
#       xG+xAG_90  npxG_90  npxG+xAG_90
# 2511       0.54      0.1         0.44
#
# [1 rows x 37 columns]

# %%
bochum = top_players[top_players["Squad"] == "Bochum"]
suma_boch = bochum.select_dtypes(include='number').sum()
suma_bochum = pd.DataFrame(suma_boch).T

# %%
bochum_final = pd.concat([bochum, suma_bochum], ignore_index=True)

# %%
bochum_final

# %%
ratio_goles_stoger = (7 / 41) * 100
ratio_asist_stoger = (10 / 30) * 100
ratio_xag_stoger = (9.9 / 30.7) * 100
ratio_prgc_stoger = (81 / 400) * 100
ratio_prgp_stoger = (283 / 1151) * 100
ratio_min_stoger = (2668 / (34 * 90)) * 100

# %%
print(f"Kevin Stöger ha conseguido el {round(ratio_goles_stoger, 2)}% de los goles del Bochum en la 23/24.")
print(f"Kevin Stöger ha conseguido el {round(ratio_asist_stoger, 2)}% de las asistencias del Bochum en la 23/24.")
print(f"Kevin Stöger ha conseguido el {round(ratio_xag_stoger, 2)}% de las asistencias esperadas del Bochum en la 23/24.")
print(f"Kevin Stöger ha conseguido el {round(ratio_prgp_stoger, 2)}% de los pases progresivos del Bochum en la 23/24.")
print(f"Kevin Stöger ha conseguido el {round(ratio_prgc_stoger, 2)}% de las conducciones progresivas del Bochum en la 23/24.")
print(f"Kevin Stöger ha jugado el {round(ratio_min_stoger, 2)}% de los minutos de la temporada.")
# Out:
# Kevin Stöger ha conseguido el 17.07% de los goles del Bochum en la 23/24.
# Kevin Stöger ha conseguido el 33.33% de las asistencias del Bochum en la 23/24.
# Kevin Stöger ha conseguido el 32.25% de las asistencias esperadas del Bochum en la 23/24.
# Kevin Stöger ha conseguido el 24.59% de los pases progresivos del Bochum en la 23/24.
# Kevin Stöger ha conseguido el 20.25% de las conducciones progresivas del Bochum en la 23/24.
# Kevin Stöger ha jugado el 87.19% de los minutos de la temporada.

# %% [markdown]
# ### Luis Alberto vs Lazio

# %%
luis_alberto = top_players.loc[top_players["Player"] == "Luis Alberto"]

# %%
luis_alberto

# %%
lazio = top_players[top_players["Squad"] == "Lazio"]
suma_laz = lazio.select_dtypes(include='number').sum()
suma_lazio = pd.DataFrame(suma_laz).T

# %%
lazio_final = pd.concat([lazio, suma_lazio], ignore_index=True)

# %%
lazio_final

# %%
ratio_goles_luis = (5 / 41) * 100
ratio_asist_luis = (7 / 30) * 100
ratio_xag_luis = (4.7 / 30.7) * 100
ratio_prgc_luis = (83 / 400) * 100
ratio_prgp_luis = (212 / 1151) * 100
ratio_min_luis = (2311 / (38 * 90)) * 100

# %%
print(f"Luis Alberto ha conseguido el {round(ratio_goles_luis, 2)}% de los goles del Lazio en la 23/24.")
print(f"Luis Alberto ha conseguido el {round(ratio_asist_luis, 2)}% de las asistencias del Lazio en la 23/24.")
print(f"Luis Alberto ha conseguido el {round(ratio_xag_luis, 2)}% de las asistencias esperadas del Lazio en la 23/24.")
print(f"Luis Alberto ha conseguido el {round(ratio_prgp_luis, 2)}% de los pases progresivos del Lazio en la 23/24.")
print(f"Luis Alberto ha conseguido el {round(ratio_prgc_luis, 2)}% de las conducciones progresivas del Lazio en la 23/24.")
print(f"Luis Alberto ha jugado el {round(ratio_min_luis, 2)}% de los minutos de la temporada.")
# Out:
# Luis Alberto ha conseguido el 12.2% de los goles del Lazio en la 23/24.
# Luis Alberto ha conseguido el 23.33% de las asistencias del Lazio en la 23/24.
# Luis Alberto ha conseguido el 15.31% de las asistencias esperadas del Lazio en la 23/24.
# Luis Alberto ha conseguido el 18.42% de los pases progresivos del Lazio en la 23/24.
# Luis Alberto ha conseguido el 20.75% de las conducciones progresivas del Lazio en la 23/24.
# Luis Alberto ha jugado el 67.57% de los minutos de la temporada.

# %% [markdown]
# ### Rodri vs Manchester City

# %%
rodri = top_players.loc[(top_players["Player"] == "Rodri") & (top_players["Squad"] == "Manchester City")]

# %%
rodri

# %%
city = top_players[top_players["Squad"] == "Manchester City"]
suma_mcit = city.select_dtypes(include='number').sum()
suma_city = pd.DataFrame(suma_mcit).T

# %%
city_final = pd.concat([city, suma_city], ignore_index=True)

# %%
city_final

# %%
ratio_goles_rodri = (8 / 94) * 100
ratio_asist_rodri = (9 / 69) * 100
ratio_xag_rodri = (3.9 / 60.7) * 100
ratio_prgc_rodri = (76 / 1127) * 100
ratio_prgp_rodri = (376 / 2060) * 100
ratio_min_rodri = (2931 / (38 * 90)) * 100

# %%
print(f"Rodri ha conseguido el {round(ratio_goles_luis, 2)}% de los goles del Manchester City en la 23/24.")
print(f"Rodri ha conseguido el {round(ratio_asist_luis, 2)}% de las asistencias del Manchester City en la 23/24.")
print(f"Rodri ha conseguido el {round(ratio_xag_luis, 2)}% de las asistencias esperadas del Manchester City en la 23/24.")
print(f"Rodri ha conseguido el {round(ratio_prgp_luis, 2)}% de los pases progresivos del Manchester City en la 23/24.")
print(f"Rodri ha conseguido el {round(ratio_prgc_luis, 2)}% de las conducciones progresivas del Manchester City en la 23/24.")
print(f"Rodri ha jugado el {round(ratio_min_luis, 2)}% de los minutos de la temporada.")
# Out:
# Rodri ha conseguido el 12.2% de los goles del Manchester City en la 23/24.
# Rodri ha conseguido el 23.33% de las asistencias del Manchester City en la 23/24.
# Rodri ha conseguido el 15.31% de las asistencias esperadas del Manchester City en la 23/24.
# Rodri ha conseguido el 18.42% de los pases progresivos del Manchester City en la 23/24.
# Rodri ha conseguido el 20.75% de las conducciones progresivas del Manchester City en la 23/24.
# Rodri ha jugado el 67.57% de los minutos de la temporada.

# %%
########################
########################

# %%
leverkusen_goles_partido = 89 / 34
leverkusen_puntos_partido = 90 / 34

print(leverkusen_goles_partido)
print(leverkusen_puntos_partido)
# Out:
# 2.6176470588235294
# 2.6470588235294117
