# %% [markdown]
# ![imagen](https://www.sportsessionplanner.com/uploads/images/session_transitions/7905031.jpg)

# %% [markdown]
# # INFORMACIÓN DEL PROYECTO

# %% [markdown]
# # 🏆 Bajo el radar: buscando al nuevo maestro del mediocampo del Real Madrid 🏆

# %% [markdown]
# ### 🎯 **Objetivo del Proyecto** 🎯
#
# Este proyecto tiene como objetivo **identificar a un sustituto válido** para el destacado mediocampista **Toni Kroos**, aprovechando un análisis de datos de jugadores de las **cinco grandes ligas europeas**:
#
# - **LaLiga**
# - **Premier League**
# - **Bundesliga**
# - **Serie A**
# - **Ligue 1**
#
# ### 📊 **Metodología:** 📊
#
# A través de un **análisis exploratorio de datos (EDA)**, se evaluarán métricas clave como:
#
# - **Goles**
# - **Asistencias**
# - **Minutos jugados**
# - **Contribuciones defensivas y ofensivas**
# - **Pases progresivos**
# - **Etc.**
#
#
# Estos datos se compararán con el rendimiento de Kroos para encontrar el candidato ideal.

# %% [markdown]
# ### 🧐 **Hipótesis General** 🧐
#
# > "Existen jugadores en las **cinco grandes ligas europeas** que, al analizar sus estadísticas de rendimiento en la temporada **23/24**, demuestran ser **sustitutos válidos** de **Toni Kroos** en la posición de mediocentro"

# %% [markdown]
# ##### ⚽ **H1: Desempeño en goles y asistencias**
# >>> ¿Existen jugadores cuya producción de goles y asistencias sea comparable a la de **Toni Kroos**?
#
# ##### 📈 **H2: Eficiencia en pases y asistencias**
# >>> ¿Qué jugadores destacan en la eficiencia de sus pases y asistencias?
#
# ##### 🛡️ **H3: Contribución defensiva**
# >>> ¿Los posibles sustitutos de Kroos tienen un aporte defensivo similar a **Toni Kroos**?
#
# ##### 🔥 **H4: Contribución ofensiva**
# >>> ¿Cuáles son los jugadores que destacan en su contribución ofensiva en comparación con **Kroos**?
#
# ##### ⏱️ **H5: Minutos disputados**
# >>> ¿Los jugadores candidatos han acumulado suficientes minutos en la temporada?

# %% [markdown]
# ## OBTENCIÓN DE LOS DATOS

# %% [markdown]
# ### DATASETS Y FUENTES ALTERNATIVAS DE DATOS

# %%
import pandas as pd

# %%
top_players = pd.read_csv("./data/top5-players.csv")
fuente_1 = "https://www.kaggle.com/datasets/orkunaktas/all-football-players-stats-in-top-5-leagues-2324?resource=download"

# %%
top_players.head(10)
# Out:
#    Rk             Player   Nation    Pos           Squad                Comp  \
# 0   1         Max Aarons  eng ENG     DF     Bournemouth  eng Premier League
# 1   2   Brenden Aaronson   us USA  MF,FW    Union Berlin       de Bundesliga
# 2   3    Paxten Aaronson   us USA     MF  Eint Frankfurt       de Bundesliga
# 3   4  Keyliane Abdallah   fr FRA     FW       Marseille          fr Ligue 1
# 4   5   Yunis Abdelhamid   ma MAR     DF           Reims          fr Ligue 1
# 5   6  Salis Abdul Samed   gh GHA     MF            Lens          fr Ligue 1
# 6   7      Nabil Aberdin   fr FRA     DF          Getafe          es La Liga
# 7   8    Laurent Abergel   fr FRA     MF         Lorient          fr Ligue 1
# 8   9     Matthis Abline   fr FRA     FW          Nantes          fr Ligue 1
# 9  10              Abner   br BRA     DF           Betis          es La Liga
#
#     Age    Born  MP  Starts  ...  Gls_90  Ast_90  G+A_90  G-PK_90  G+A-PK_90  \
# ...

# %%
top_players.shape
# Out:
# (2852, 37)
